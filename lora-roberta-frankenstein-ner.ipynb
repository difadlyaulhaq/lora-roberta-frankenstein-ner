# %% [markdown]
# #Library

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# #LOAD DATA

# %%
data = pd.read_csv('frankenstein_clean.txt', sep='\t', header=None, names=['line'])
data.head()
# Out:
#                                                 line
# 0                                   --- Letter 1 ---
# 1                          To Mrs. Saville, England.
# 2                   St. Petersburgh, Dec. 11th, 17—.
# 3  You will rejoice to hear that no disaster has ...
# 4  an enterprise which you have regarded with suc...
